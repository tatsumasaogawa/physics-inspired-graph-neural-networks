# %% [markdown]
# 参考: https://labo-code.com/python/data-analysis/inputfile-eachrow/

# %%
import numpy as np

# %% [markdown]
# # データの加工

# %% [markdown]
# ## 1-layer gnn

# %%
for n in range(100, 1001, 100):
    for d in range(3, 6, 2):
        mc_n_d = []
        time_n_d = []
        for seed_value in range(20):
            input_data = open('../1_layer_gnn/data/1gnn_n' + str(n) + '_d' + str(d) + '_seed' + str(seed_value) + '.dat', 'r')

            # 一行ずつ読み込んでは表示する
            for rows in input_data:
                # コメントアウト部分を省く処理
                if rows[0]=='#':
                    continue
                
                # 値を変数に格納する
                row = rows.rstrip('\n').split(' ')
                mc_size = float(row[0])
                tot_time = float(row[2])

                mc_n_d.append(mc_size)
                time_n_d.append(tot_time)

            # ファイルを閉じる
            input_data.close()
        
        ave_mc = np.mean(mc_n_d)
        std_mc = np.std(mc_n_d)
        ave_time = np.mean(time_n_d)
        std_time = np.std(time_n_d)

        outfile = open('../1_layer_gnn/processed_data/1gnn_n' + str(n) + '_d' + str(d) + '.dat','w')
        outfile.write('# 01: average mc size 02: std of mc size 03: average solution time 04: std of solution time\n')
        outfile.write(str(ave_mc) + ' ' + str(std_mc) + ' ' + str(ave_time) + ' ' + str(std_time) + '\n')
        outfile.close()

for n in range(2000, 10001, 1000):
    for d in range(3, 6, 2):
        mc_n_d = []
        time_n_d = []
        for seed_value in range(20):
            input_data = open('../1_layer_gnn/data/1gnn_n' + str(n) + '_d' + str(d) + '_seed' + str(seed_value) + '.dat', 'r')

            # 一行ずつ読み込んでは表示する
            for rows in input_data:
                # コメントアウト部分を省く処理
                if rows[0]=='#':
                    continue
                
                # 値を変数に格納する
                row = rows.rstrip('\n').split(' ')
                mc_size = float(row[0])
                tot_time = float(row[2])

                mc_n_d.append(mc_size)
                time_n_d.append(tot_time)

            # ファイルを閉じる
            input_data.close()
        
        ave_mc = np.mean(mc_n_d)
        std_mc = np.std(mc_n_d)
        ave_time = np.mean(time_n_d)
        std_time = np.std(time_n_d)

        outfile = open('../1_layer_gnn/processed_data/1gnn_n' + str(n) + '_d' + str(d) + '.dat','w')
        outfile.write('# 01: average mc size 02: std of mc size 03: average solution time 04: std of solution time\n')
        outfile.write(str(ave_mc) + ' ' + str(std_mc) + ' ' + str(ave_time) + ' ' + str(std_time) + '\n')
        outfile.close()

# %% [markdown]
# ## 2-layer gnn

# %%
for n in range(100, 1001, 100):
    for d in range(3, 6, 2):
        mc_n_d = []
        time_n_d = []
        for seed_value in range(20):
            input_data = open('../2_layer_gnn/data/2gnn_n' + str(n) + '_d' + str(d) + '_seed' + str(seed_value) + '.dat', 'r')

            # 一行ずつ読み込んでは表示する
            for rows in input_data:
                # コメントアウト部分を省く処理
                if rows[0]=='#':
                    continue
                
                # 値を変数に格納する
                row = rows.rstrip('\n').split(' ')
                mc_size = float(row[0])
                tot_time = float(row[2])

                mc_n_d.append(mc_size)
                time_n_d.append(tot_time)

            # ファイルを閉じる
            input_data.close()
        
        ave_mc = np.mean(mc_n_d)
        std_mc = np.std(mc_n_d)
        ave_time = np.mean(time_n_d)
        std_time = np.std(time_n_d)

        outfile = open('../2_layer_gnn/processed_data/2gnn_n' + str(n) + '_d' + str(d) + '.dat','w')
        outfile.write('# 01: average mc size 02: std of mc size 03: average solution time 04: std of solution time\n')
        outfile.write(str(ave_mc) + ' ' + str(std_mc) + ' ' + str(ave_time) + ' ' + str(std_time) + '\n')
        outfile.close()

for n in range(2000, 10001, 1000):
    for d in range(3, 6, 2):
        mc_n_d = []
        time_n_d = []
        for seed_value in range(20):
            input_data = open('../2_layer_gnn/data/2gnn_n' + str(n) + '_d' + str(d) + '_seed' + str(seed_value) + '.dat', 'r')

            # 一行ずつ読み込んでは表示する
            for rows in input_data:
                # コメントアウト部分を省く処理
                if rows[0]=='#':
                    continue
                
                # 値を変数に格納する
                row = rows.rstrip('\n').split(' ')
                mc_size = float(row[0])
                tot_time = float(row[2])

                mc_n_d.append(mc_size)
                time_n_d.append(tot_time)

            # ファイルを閉じる
            input_data.close()
        
        ave_mc = np.mean(mc_n_d)
        std_mc = np.std(mc_n_d)
        ave_time = np.mean(time_n_d)
        std_time = np.std(time_n_d)

        outfile = open('../2_layer_gnn/processed_data/2gnn_n' + str(n) + '_d' + str(d) + '.dat','w')
        outfile.write('# 01: average mc size 02: std of mc size 03: average solution time 04: std of solution time\n')
        outfile.write(str(ave_mc) + ' ' + str(std_mc) + ' ' + str(ave_time) + ' ' + str(std_time) + '\n')
        outfile.close()

# %% [markdown]
# ## mfa

# %%
for n in range(100, 1001, 100):
    for d in range(3, 6, 2):
        mc_n_d = []
        time_n_d = []
        for seed_value in range(20):
            input_data = open('../mfa/data/mfa_n' + str(n) + '_d' + str(d) + '_seed' + str(seed_value) + '.dat', 'r')

            # 一行ずつ読み込んでは表示する
            for rows in input_data:
                # コメントアウト部分を省く処理
                if rows[0]=='#':
                    continue
                
                # 値を変数に格納する
                row = rows.rstrip('\n').split(' ')
                mc_size = float(row[0])
                tot_time = float(row[2])

                mc_n_d.append(mc_size)
                time_n_d.append(tot_time)

            # ファイルを閉じる
            input_data.close()
        
        ave_mc = np.mean(mc_n_d)
        std_mc = np.std(mc_n_d)
        ave_time = np.mean(time_n_d)
        std_time = np.std(time_n_d)

        outfile = open('../mfa/processed_data/mfa_n' + str(n) + '_d' + str(d) + '.dat','w')
        outfile.write('# 01: average mc size 02: std of mc size 03: average solution time 04: std og solution time\n')
        outfile.write(str(ave_mc) + ' ' + str(std_mc) + ' ' + str(ave_time) + ' ' + str(std_time) + '\n')
        outfile.close()

for n in range(2000, 2001, 1000):
    for d in range(3, 6, 2):
        mc_n_d = []
        time_n_d = []
        for seed_value in range(20):
            input_data = open('../mfa/data/mfa_n' + str(n) + '_d' + str(d) + '_seed' + str(seed_value) + '.dat', 'r')

            # 一行ずつ読み込んでは表示する
            for rows in input_data:
                # コメントアウト部分を省く処理
                if rows[0]=='#':
                    continue
                
                # 値を変数に格納する
                row = rows.rstrip('\n').split(' ')
                mc_size = float(row[0])
                tot_time = float(row[2])

                mc_n_d.append(mc_size)
                time_n_d.append(tot_time)

            # ファイルを閉じる
            input_data.close()
        
        ave_mc = np.mean(mc_n_d)
        std_mc = np.std(mc_n_d)
        ave_time = np.mean(time_n_d)
        std_time = np.std(time_n_d)

        outfile = open('../mfa/processed_data/mfa_n' + str(n) + '_d' + str(d) + '.dat','w')
        outfile.write('# 01: average mc size 02: std of mc size 03: average solution time 04: std og solution time\n')
        outfile.write(str(ave_mc) + ' ' + str(std_mc) + ' ' + str(ave_time) + ' ' + str(std_time) + '\n')
        outfile.close()

# %% [markdown]
# # プロット作成用のリスト作成

# %% [markdown]
# ## 1-layer gnn

# %%
ave_mc_1gnn = []
std_mc_1gnn = []
ave_time_1gnn = []
std_time_1gnn = []

for d in range(3, 6, 2):
    ave_mc_1gnn_d = []
    std_mc_1gnn_d = []
    ave_time_1gnn_d = []
    std_time_1gnn_d = []
    
    for n in range(100, 1001, 100):
        input_data = open('../1_layer_gnn/processed_data/1gnn_n' + str(n) + '_d' + str(d) + '.dat', 'r')

        # 一行ずつ読み込んでは表示する
        for rows in input_data:
            # コメントアウト部分を省く処理
            if rows[0]=='#':
                continue
            
            # 値を変数に格納する
            row = rows.rstrip('\n').split(' ')
            ave_mc_1gnn_n_d = float(row[0])
            std_mc_1gnn_n_d = float(row[1])
            ave_time_1gnn_n_d = float(row[2])
            std_time_1gnn_n_d = float(row[3])
            # print(ave_mc_1gnn_n_d, std_mc_1gnn_n_d)
        
        ave_mc_1gnn_d.append(ave_mc_1gnn_n_d)
        std_mc_1gnn_d.append(std_mc_1gnn_n_d)
        ave_time_1gnn_d.append(ave_time_1gnn_n_d)
        std_time_1gnn_d.append(std_time_1gnn_n_d)

        # ファイルを閉じる
        input_data.close()
    
    for n in range(2000, 10001, 1000):
        input_data = open('../1_layer_gnn/processed_data/1gnn_n' + str(n) + '_d' + str(d) + '.dat', 'r')

        # 一行ずつ読み込んでは表示する
        for rows in input_data:
            # コメントアウト部分を省く処理
            if rows[0]=='#':
                continue
            
            # 値を変数に格納する
            row = rows.rstrip('\n').split(' ')
            ave_mc_1gnn_n_d = float(row[0])
            std_mc_1gnn_n_d = float(row[1])
            ave_time_1gnn_n_d = float(row[2])
            std_time_1gnn_n_d = float(row[3])
            # print(ave_mc_1gnn_n_d, std_mc_1gnn_n_d)
        
        ave_mc_1gnn_d.append(ave_mc_1gnn_n_d)
        std_mc_1gnn_d.append(std_mc_1gnn_n_d)
        ave_time_1gnn_d.append(ave_time_1gnn_n_d)
        std_time_1gnn_d.append(std_time_1gnn_n_d)

        # ファイルを閉じる
        input_data.close()

    ave_mc_1gnn.append(ave_mc_1gnn_d)
    std_mc_1gnn.append(std_mc_1gnn_d)
    ave_time_1gnn.append(ave_time_1gnn_d)
    std_time_1gnn.append(std_time_1gnn_d)

# %% [markdown]
# ## mfa

# %%
ave_mc_mfa = []
std_mc_mfa = []
ave_time_mfa = []
std_time_mfa = []

for d in range(3, 6, 2):
    ave_mc_mfa_d = []
    std_mc_mfa_d = []
    ave_time_mfa_d = []
    std_time_mfa_d = []
    
    for n in range(100, 1001, 100):
        input_data = open('../mfa/processed_data/mfa_n' + str(n) + '_d' + str(d) + '.dat', 'r')
        
        for rows in input_data:
            if rows[0]=='#':
                continue

            row = rows.rstrip('\n').split(' ')
            ave_mc_mfa_n_d = float(row[0])
            std_mc_mfa_n_d = float(row[1])
            # print(std_mc_mfa_n_d)
            ave_time_mfa_n_d = float(row[2])
            std_time_mfa_n_d = float(row[3])

        ave_mc_mfa_d.append(ave_mc_mfa_n_d)
        std_mc_mfa_d.append(std_mc_mfa_n_d)
        ave_time_mfa_d.append(ave_time_mfa_n_d)
        std_time_mfa_d.append(std_time_mfa_n_d)

        # ファイルを閉じる
        input_data.close()
    
    for n in range(2000, 2001, 1000):
        input_data = open('../mfa/processed_data/mfa_n' + str(n) + '_d' + str(d) + '.dat', 'r')
        
        for rows in input_data:
            if rows[0]=='#':
                continue

            row = rows.rstrip('\n').split(' ')
            ave_mc_mfa_n_d = float(row[0])
            std_mc_mfa_n_d = float(row[1])
            # print(std_mc_mfa_n_d)
            ave_time_mfa_n_d = float(row[2])
            std_time_mfa_n_d = float(row[3])

        ave_mc_mfa_d.append(ave_mc_mfa_n_d)
        std_mc_mfa_d.append(std_mc_mfa_n_d)
        ave_time_mfa_d.append(ave_time_mfa_n_d)
        std_time_mfa_d.append(std_time_mfa_n_d)

        # ファイルを閉じる
        input_data.close()

    ave_mc_mfa.append(ave_mc_mfa_d)
    std_mc_mfa.append(std_mc_mfa_d)
    ave_time_mfa.append(ave_time_mfa_d)
    std_time_mfa.append(std_time_mfa_d)

# %% [markdown]
# ## 2-layer gnn

# %%
ave_mc_2gnn = []
std_mc_2gnn = []
ave_time_2gnn = []
std_time_2gnn = []

for d in range(3, 6, 2):
    ave_mc_2gnn_d = []
    std_mc_2gnn_d = []
    ave_time_2gnn_d = []
    std_time_2gnn_d = []
    
    for n in range(100, 1001, 100):
        input_data = open('../2_layer_gnn/processed_data/2gnn_n' + str(n) + '_d' + str(d) + '.dat', 'r')

        # 一行ずつ読み込んでは表示する
        for rows in input_data:
            # コメントアウト部分を省く処理
            if rows[0]=='#':
                continue
            
            # 値を変数に格納する
            row = rows.rstrip('\n').split(' ')
            ave_mc_2gnn_n_d = float(row[0])
            std_mc_2gnn_n_d = float(row[1])
            ave_time_2gnn_n_d = float(row[2])
            std_time_2gnn_n_d = float(row[3])
            # print(ave_mc_1gnn_n_d, std_mc_1gnn_n_d)
        
        ave_mc_2gnn_d.append(ave_mc_2gnn_n_d)
        std_mc_2gnn_d.append(std_mc_2gnn_n_d)
        ave_time_2gnn_d.append(ave_time_2gnn_n_d)
        std_time_2gnn_d.append(std_time_2gnn_n_d)

        # ファイルを閉じる
        input_data.close()
    
    for n in range(2000, 10001, 1000):
        input_data = open('../2_layer_gnn/processed_data/2gnn_n' + str(n) + '_d' + str(d) + '.dat', 'r')

        # 一行ずつ読み込んでは表示する
        for rows in input_data:
            # コメントアウト部分を省く処理
            if rows[0]=='#':
                continue
            
            # 値を変数に格納する
            row = rows.rstrip('\n').split(' ')
            ave_mc_2gnn_n_d = float(row[0])
            std_mc_2gnn_n_d = float(row[1])
            ave_time_2gnn_n_d = float(row[2])
            std_time_2gnn_n_d = float(row[3])
            # print(ave_mc_1gnn_n_d, std_mc_1gnn_n_d)
        
        ave_mc_2gnn_d.append(ave_mc_2gnn_n_d)
        std_mc_2gnn_d.append(std_mc_2gnn_n_d)
        ave_time_2gnn_d.append(ave_time_2gnn_n_d)
        std_time_2gnn_d.append(std_time_2gnn_n_d)

        # ファイルを閉じる
        input_data.close()

    ave_mc_2gnn.append(ave_mc_2gnn_d)
    std_mc_2gnn.append(std_mc_2gnn_d)
    ave_time_2gnn.append(ave_time_2gnn_d)
    std_time_2gnn.append(std_time_2gnn_d)

# %% [markdown]
# # プロット作成

# %%
def ub(d, n):
    return (d / 4 + 0.7632 * np.sqrt(d / 4)) * n

# %% [markdown]
# ## 最大カットサイズとその上界に対する比

# %%
from matplotlib import pyplot as plt
import japanize_matplotlib

x_1 = np.array(list(range(100, 1001, 100)) + list(range(2000, 10001, 1000)))
x_2 = np.array(list(range(100, 1001, 100)) + list(range(2000, 2001, 1000)))
x_3 = np.array(list(range(100, 1001, 100)))

fig, ax = plt.subplots()
ax.errorbar(x_1, ave_mc_1gnn[0], yerr=std_mc_1gnn[0], capsize=3)
ax.errorbar(x_1, ave_mc_2gnn[0], yerr=std_mc_2gnn[0], capsize=3)
ax.errorbar(x_2, ave_mc_mfa[0], yerr=std_mc_mfa[0], capsize=3)
ax.plot(x_1, ub(3, x_1))
ax.set_xlabel("n")
ax.set_ylabel('MC size')
plt.legend(["upper bound", "1-layer GNN", "2-layer GNN", "MFA"])
plt.title('次数d=3のランダム正則グラフに対する最大カットサイズ\n(エラーバー: 標準偏差)')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x_1, ave_mc_1gnn[0] / ub(3, x_1), marker = "o", markersize=4)
ax.plot(x_1, ave_mc_2gnn[0] / ub(3, x_1), marker = "o", markersize=4)
ax.plot(x_2, ave_mc_mfa[0] / ub(3, x_2), marker = "o", markersize=4)
ax.set_xscale("log")
ax.set_xlabel("n")
ax.set_ylabel('ratio')
plt.legend(["1-layer GNN", "2-layer GNN", "MFA"])
plt.title('次数d=3のランダム正則グラフに対する最大カットサイズの近似比')
plt.show()

# %%
fig, ax = plt.subplots()
ax.errorbar(x_1, ave_mc_1gnn[1], yerr=std_mc_1gnn[1], capsize=3)
ax.errorbar(x_1, ave_mc_2gnn[1], yerr=std_mc_2gnn[1], capsize=3)
ax.errorbar(x_2, ave_mc_mfa[1], yerr=std_mc_mfa[1], capsize=3)
# ax.errorbar(x, ave_mc_bp[1], yerr=std_mc_bp[1], capsize=3)
ax.plot(x_1, ub(5, x_1))
ax.set_xlabel('n')
ax.set_ylabel('MC size')
plt.legend(["upper bound", "1-layer GNN", "2-layer GNN", "MFA"])
plt.title('次数d=5のランダム正則グラフに対する最大カットサイズ\n(エラーバー: 標準偏差)')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x_1, ave_mc_1gnn[1] / ub(5, x_1), marker = "o", markersize=4)
ax.plot(x_1, ave_mc_2gnn[1] / ub(5, x_1), marker = "o", markersize=4)
ax.plot(x_2, ave_mc_mfa[1] / ub(5, x_2), marker = "o", markersize=4)
# ax.plot(x, ave_mc_bp[1] / ub(5, x))
ax.set_xscale("log")
ax.set_xlabel("n")
ax.set_ylabel('ratio')
plt.legend(["1-layer GNN", "2-layer GNN", "MFA"])
plt.title('次数d=5のランダム正則グラフに対する最大カットサイズの近似比')
plt.show()

# %% [markdown]
# ## 実行時間

# %%
def func(X, a, b):
    Y = a * X ** b
    return Y

# %%
from scipy.optimize import curve_fit
popt_1gnn_d3, pcov = curve_fit(func,x_1,ave_time_1gnn[0])
popt_1gnn_d3
# Out:
# array([38.01154297,  0.10763688])

# %%
popt_2gnn_d3, pcov = curve_fit(func,x_1,ave_time_2gnn[0])
popt_2gnn_d3
# Out:
# array([1.50205713e+02, 1.20095271e-02])

# %%
popt_mfa_d3, pcov = curve_fit(func,x_2,ave_time_mfa[0])
popt_mfa_d3
# Out:
# array([2.16137435e-06, 2.62837738e+00])

# %%
fig, ax = plt.subplots()
ax.errorbar(x_1, ave_time_1gnn[0], yerr=std_time_1gnn[0], capsize=3, linestyle="None", marker="o", markersize=4)
ax.errorbar(x_1, ave_time_2gnn[0], yerr=std_time_2gnn[0], capsize=3, linestyle="None", marker="o", markersize=4)
ax.errorbar(x_2, ave_time_mfa[0], yerr=std_time_mfa[0], capsize=3, linestyle="None", marker="o", markersize=4)
ax.plot(x_1, func(x_1, popt_1gnn_d3[0], popt_1gnn_d3[1]), color="tab:blue")
ax.plot(x_1, func(x_1, popt_2gnn_d3[0], popt_2gnn_d3[1]), color="tab:orange")
ax.plot(x_2, func(x_2, popt_mfa_d3[0], popt_mfa_d3[1]), color="tab:green")

ax.set_xscale("log")
ax.set_xlabel('n')
ax.set_ylabel('solution time [s]')
plt.legend(["1-layer GNN", "2-layer GNN", "MFA"])
plt.title('次数d=3のランダム正則グラフに対する実行時間\n(エラーバー: 標準偏差)')
plt.show()

# %%
popt_1gnn_d5, pcov = curve_fit(func,x_1,ave_time_1gnn[1])
popt_1gnn_d5
# Out:
# array([7.92145941e+01, 3.09077205e-02])

# %%
popt_2gnn_d5, pcov = curve_fit(func,x_1,ave_time_2gnn[1])
popt_2gnn_d5
# Out:
# array([ 4.71747469e+02, -1.33178654e-01])

# %%
popt_mfa_d5, pcov = curve_fit(func,x_2,ave_time_mfa[1])
popt_mfa_d5
# Out:
# array([2.21705366e-06, 2.65823558e+00])

# %%
fig, ax = plt.subplots()
ax.errorbar(x_1, ave_time_1gnn[1], yerr=std_time_1gnn[1], capsize=3, linestyle="None", marker="o", markersize=4)
ax.errorbar(x_1, ave_time_2gnn[1], yerr=std_time_2gnn[1], capsize=3, linestyle="None", marker="o", markersize=4)
ax.errorbar(x_2, ave_time_mfa[1], yerr=std_time_mfa[1], capsize=3, linestyle="None", marker="o", markersize=4)
ax.plot(x_1, func(x_1, popt_1gnn_d5[0], popt_1gnn_d5[1]), color="tab:blue")
ax.plot(x_1, func(x_1, popt_2gnn_d5[0], popt_2gnn_d5[1]), color="tab:orange")
ax.plot(x_2, func(x_2, popt_mfa_d5[0], popt_mfa_d5[1]), color="tab:green")
ax.set_xscale("log")
ax.set_xlabel('n')
ax.set_ylabel('solution time [s]')
plt.legend(["1-layer GNN", "2-layer GNN", "MFA"])
plt.title('次数d=5のランダム正則グラフに対する実行時間\n(エラーバー: 標準偏差)')
plt.show()
